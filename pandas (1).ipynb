# %%
Get the columns or features of  of the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
url=r"C:\Users\User\Desktop\BlackFriday.csv"
df=pd.read_csv(url)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %% [markdown]
# How many observations are there in the dataset

# %%
df.index
# Out:
# RangeIndex(start=0, stop=537577, step=1)

# %% [markdown]
# What are the missing values ? How many for each category?

# %%
#s=df.isna().sum()
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [markdown]
# How many unique values for UserId and Product Id

# %%
print("unique values in UserID",df['User_ID'].nunique())
print("unique values in ProductID",df['Product_ID'].nunique())
# Out:
# unique values in UserID 5891
# unique values in ProductID 3623

# %% [markdown]
# How many males and females in the data set?

# %%
f=0
for gender in df['Gender']:
    if(gender=='F'):
        f+=1
print( "the number of females in data set:",f)
d=0
for gender in df['Gender']:
    if(gender=='M'):
        d+=1
print( "the number of males in data set:",d)
# Out:
# the number of females in data set: 132197
# the number of males in data set: 405380

# %% [markdown]
# Print a frequency chart for the age groups

# %%
df['Age'].value_counts().plot('bar')
plt.show(df['Age'].all())

# %% [markdown]
# What is the distribution of marital status of people?

# %%
df['Marital_Status'].value_counts().plot('bar')
plt.show(df['Marital_Status'].all())

# %%
Create 3 files for each of the city category

# %%
df['City_Category'].isany("a")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-d0f74a89b5bf> in <module>()
# ----> 1 df['City_Category'].isany("a")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'isany'

# %%
Draw a frequency chart for the occupation

# %%
df['Occupation'].value_counts().plot('bar')
plt.show(df['Occupation'].all())

# %% [markdown]
# What is the purchase value for males and females

# %%
a=df[(df.Gender=="M")].Purchase.sum()
print("the purchase value of male is",a)
b=df[(df.Gender=="F")].Purchase.sum()
print("the purchase value of male is",b)
# Out:
# the purchase value of male is 3853044357
# the purchase value of male is 1164624021

# %% [markdown]
# Add an additional column for country (Country is US)

# %%
df['Country']=pd.Series(["US"],index=df.index)
df
# Out:
#           User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001.0  P00069042      F   0-17        10.0             A
# 1       1000001.0  P00248942      F   0-17        10.0             A
# 2       1000001.0  P00087842      F   0-17        10.0             A
# 3       1000001.0  P00085442      F   0-17        10.0             A
# 4       1000002.0  P00285442      M    55+        16.0             C
# 5       1000003.0  P00193542      M  26-35        15.0             A
# 6       1000004.0  P00184942      M  46-50         7.0             B
# 7       1000004.0  P00346142      M  46-50         7.0             B
# 8       1000004.0   P0097242      M  46-50         7.0             B
# 9       1000005.0  P00274942      M  26-35        20.0             A
# 10      1000005.0  P00251242      M  26-35        20.0             A
# 11      1000005.0  P00014542      M  26-35        20.0             A
# 12      1000005.0  P00031342      M  26-35        20.0             A
# ...

# %% [markdown]
# Show the head of the data frame

# %%
df.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %% [markdown]
# Show the last part of the dataframe

# %%
df.tail(5)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 537572                 2.0                 NaN     11664
# ...

# %% [markdown]
# Get the details of  user 1000001

# %%
df[df.User_ID==1000001]
# Out:
#           User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001.0  P00069042      F  0-17        10.0             A
# 1       1000001.0  P00248942      F  0-17        10.0             A
# 2       1000001.0  P00087842      F  0-17        10.0             A
# 3       1000001.0  P00085442      F  0-17        10.0             A
# 39180   1000001.0  P00085942      F  0-17        10.0             A
# 78144   1000001.0  P00102642      F  0-17        10.0             A
# 78145   1000001.0  P00110842      F  0-17        10.0             A
# 78146   1000001.0  P00004842      F  0-17        10.0             A
# 116848  1000001.0  P00117942      F  0-17        10.0             A
# 116849  1000001.0  P00258742      F  0-17        10.0             A
# 116850  1000001.0  P00142242      F  0-17        10.0             A
# 116851  1000001.0  P00000142      F  0-17        10.0             A
# 155570  1000001.0  P00297042      F  0-17        10.0             A
# ...

# %% [markdown]
# Get the details of the 50th observation

# %%
df.iloc[49]
# Out:
# User_ID                       1.00001e+06
# Product_ID                      P00189642
# Gender                                  F
# Age                                 26-35
# Occupation                              1
# City_Category                           C
# Stay_In_Current_City_Years              1
# Marital_Status                          0
# Product_Category_1                      8
# Product_Category_2                     13
# Product_Category_3                    NaN
# Purchase                             8027
# 0                                     NaN
# Country                                US
# Name: 49, dtype: object

# %% [markdown]
# Create a small data frame with only user_id, age and purchase

# %%
d=df[['User_ID','Age','Purchase']]
d
# Out:
#           User_ID    Age  Purchase
# 0       1000001.0   0-17    8370.0
# 1       1000001.0   0-17   15200.0
# 2       1000001.0   0-17    1422.0
# 3       1000001.0   0-17    1057.0
# 4       1000002.0    55+    7969.0
# 5       1000003.0  26-35   15227.0
# 6       1000004.0  46-50   19215.0
# 7       1000004.0  46-50   15854.0
# 8       1000004.0  46-50   15686.0
# 9       1000005.0  26-35    7871.0
# 10      1000005.0  26-35    5254.0
# 11      1000005.0  26-35    3957.0
# 12      1000005.0  26-35    6073.0
# 13      1000005.0  26-35   15665.0
# 14      1000006.0  51-55    5378.0
# 15      1000006.0  51-55    2079.0
# 16      1000006.0  51-55   13055.0
# 17      1000006.0  51-55    8851.0
# 18      1000007.0  36-45   11788.0
# 19      1000008.0  26-35   19614.0
# 20      1000008.0  26-35    8584.0
# 21      1000008.0  26-35    9872.0
# 22      1000008.0  26-35    9743.0
# 23      1000008.0  26-35    5982.0
# 24      1000008.0  26-35   11927.0
# 25      1000009.0  26-35   16662.0
# ...

# %% [markdown]
# Print first 10 rows of the data frame

# %%
df.head(10)
# Out:
#      User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001.0  P00069042      F   0-17        10.0             A
# 1  1000001.0  P00248942      F   0-17        10.0             A
# 2  1000001.0  P00087842      F   0-17        10.0             A
# 3  1000001.0  P00085442      F   0-17        10.0             A
# 4  1000002.0  P00285442      M    55+        16.0             C
# 5  1000003.0  P00193542      M  26-35        15.0             A
# 6  1000004.0  P00184942      M  46-50         7.0             B
# 7  1000004.0  P00346142      M  46-50         7.0             B
# 8  1000004.0   P0097242      M  46-50         7.0             B
# 9  1000005.0  P00274942      M  26-35        20.0             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# ...

# %% [markdown]
# Sort the data frame based on purchase

# %%
df.sort_values(by="Purchase")
# Out:
#           User_ID Product_ID Gender    Age  Occupation City_Category  \
# 377309  1004048.0  P00041442      F  36-45         1.0             B
# 411541  1003391.0  P00041442      M  18-25         4.0             A
# 27602   1004227.0  P00171342      M  26-35        19.0             A
# 403039  1001968.0  P00102142      M  26-35        11.0             B
# 400498  1001630.0  P00135542      M  46-50        17.0             C
# 266446  1005039.0  P00032642      F  36-45         4.0             B
# 233619  1006025.0  P00041442      F  26-35         1.0             B
# 5466    1000889.0  P00041442      M  46-50        20.0             A
# 172340  1002660.0  P00087142      M    55+        17.0             C
# 6609    1001066.0  P00200442      M  46-50        12.0             C
# 514048  1001198.0  P00212042      M   0-17        10.0             C
# 345191  1005120.0  P00066742      M  51-55         7.0             A
# 454981  1004028.0  P00041442      M  26-35         4.0             A
# ...

# %% [markdown]
# Show the summary stastics related to each of the age groups

# %%
df['Age'].describe()
# Out:
# count     537577
# unique         7
# top        26-35
# freq      214690
# Name: Age, dtype: object

# %% [markdown]
# List all purchases lower than 100 and bigger than 10000

# %%
df.query('Purchase<100' and 'Purchase>10000')
# Out:
#           User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001.0  P00248942      F   0-17        10.0             A
# 5       1000003.0  P00193542      M  26-35        15.0             A
# 6       1000004.0  P00184942      M  46-50         7.0             B
# 7       1000004.0  P00346142      M  46-50         7.0             B
# 8       1000004.0   P0097242      M  46-50         7.0             B
# 13      1000005.0  P00145042      M  26-35        20.0             A
# 16      1000006.0   P0096642      F  51-55         9.0             A
# 18      1000007.0  P00036842      M  36-45         1.0             B
# 19      1000008.0  P00249542      M  26-35        12.0             C
# 24      1000008.0  P00303442      M  26-35        12.0             C
# 25      1000009.0  P00135742      M  26-35        17.0             C
# 29      1000010.0  P00085942      F  36-45         1.0             B
# 33      1000010.0  P00058342      F  36-45         1.0             B
# ...
